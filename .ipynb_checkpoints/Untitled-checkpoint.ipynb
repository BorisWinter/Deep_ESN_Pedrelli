# %%
import pandas as pd

# %%
test = pd.read_csv('results.csv')
test2 = pd.read_csv('targets.csv')

# %%
test2
# Out:
# Empty DataFrame
# Columns: [[[29.17849731 29.18713379 29.19573975 ... 29.23751831 29.23605347
#   29.30947876]]]
# Index: []

# %%
test
# Out:
#     transient  rhos  reg  lis  iss  con   Nr  Nl  .sampling  result[0]  \
# 0        1000   0.2  0.1  0.5  1.0  0.5  100   2          1   0.005221
# 1        1000   0.2  0.0  0.5  1.0  0.5   10  10          1   0.005221
# 2        1000   1.0  0.0  0.1  1.0  0.2  200   5          1   0.005221
# 3        1000   0.2  0.0  0.5  0.1  1.0   10  10          1   0.005221
# 4        1000   1.0  0.0  0.2  1.0  0.5  200   2          1   0.005221
# 5        1000   0.5  1.0  0.1  1.0  0.2  200   2          1   0.005221
# 6        1000   0.2  1.0  0.1  1.0  0.5   10   1         10   0.005221
# 7        1000   0.2  0.1  0.2  1.0  1.0  100  10         10   0.005221
# 8        1000   0.2  0.1  0.2  1.0  0.2  200   2         10   0.005221
# 9        1000   1.0  1.0  0.5  1.0  0.5  200  10         10   0.005221
# 10       1000   1.0  0.0  0.2  1.0  0.2  100   5         10   0.005221
# 11       1000   0.5  1.0  0.1  0.1  0.2   10   5         10   0.005221
# ...
